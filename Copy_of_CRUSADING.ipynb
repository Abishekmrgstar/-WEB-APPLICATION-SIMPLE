# %% [markdown]
# <a href="https://colab.research.google.com/github/Abishekmrgstar/-WEB-APPLICATION-SIMPLE/blob/main/Copy_of_CRUSADING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 10.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 232MB/s]

# %%
# !touch data.yaml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.train(data = "/content/drive/MyDrive/MED.v1i.yolov8/data.yaml", epochs = 30)
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/MED.v1i.yolov8/test/images" , save = True, save_txt = True)
# Out:
# image 1/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-011_jpg.rf.ab943a3b81bd04ab353b01505166a4ed.jpg: 640x640 1 Medicinal-Neem, 37.2ms
# image 2/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-018_jpg.rf.7b69e03727831e646334937c9302257d.jpg: 640x640 1 Medicinal-Neem, 37.3ms
# image 3/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-019_jpg.rf.9f16c8160322e04f98db10fe86aef59c.jpg: 640x640 1 Medicinal-Neem, 43.9ms
# image 4/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-052_jpg.rf.7c5afc73c8edd8b87c09752b377fcc3a.jpg: 640x640 1 Medicinal-Neem, 49.3ms
# image 5/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-053_jpg.rf.918c30b9f8b55eb2dc1dd84d72526e67.jpg: 640x640 1 Medicinal-Neem, 37.3ms
# image 6/208 /content/drive/MyDrive/MED.v1i.yolov8/test/images/AI-S-060_jpg.rf.1d178f3b6ed7a2e0e0b60be059438146.jpg: 640x640 1 Medicinal-Neem, 37.2ms
# ...
